# %% [markdown]
# # minikube

# %% [markdown]
# ## 기본 서브커맨드

# %% [markdown]
# ### 버전

# %% [markdown]
# - minikube version

# %% [markdown]
# ### 프로필

# %% [markdown]
# - minikube profile

# %% [markdown]
# ### 생성, 가동, 중지

# %% [markdown]
# - minikube start
# - minikube stop
# - minikube pause
# - minikube unpause
# - minikube delete

# %% [markdown]
# ### 상태

# %% [markdown]
# - minikube config
# - minikube ip
# - minikube status
# - minikube dashboard

# %% [markdown]
# ## profile

# %% [markdown]
# ## config

# %% [markdown]
# - minikube config view
# - minikube config get 항목
# - minikube config set 항목
