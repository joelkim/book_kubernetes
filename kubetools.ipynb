# %% [markdown]
# # Kubernetes Tools

# %% [markdown]
# ## VM

# %% [markdown]
# - podman

# %% [markdown]
# ## Cluster

# %% [markdown]
# - minikube

# %% [markdown]
# ## Controller

# %% [markdown]
# - kubectl

# %% [markdown]
# ## Deploy

# %% [markdown]
# - helm
